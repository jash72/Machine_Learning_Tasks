# %%
import warnings
warnings.filterwarnings("ignore") #To avoid warnings.
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Top Indian Places to Visit.csv")
df
# Out:
#      Unnamed: 0      Zone           State         City  \
# 0             0  Northern           Delhi        Delhi
# 1             1  Northern           Delhi        Delhi
# 2             2  Northern           Delhi        Delhi
# 3             3  Northern           Delhi        Delhi
# 4             4  Northern           Delhi        Delhi
# ..          ...       ...             ...          ...
# 320         320   Western         Gujarat  Gandhinagar
# 321         321   Central   Uttar Pradesh         Agra
# 322         322   Central  Madhya Pradesh       Bhopal
# 323         323  Northern       Rajasthan       Jaipur
# 324         324  Northern       Rajasthan       Jaipur
#
#                              Name          Type Establishment Year  \
# 0                      India Gate  War Memorial               1921
# 1                  Humayun's Tomb          Tomb               1572
# 2               Akshardham Temple        Temple               2005
# ...

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0                            0
# Zone                                  0
# State                                 0
# City                                  0
# Name                                  0
# Type                                  0
# Establishment Year                    0
# time needed to visit in hrs           0
# Google review rating                  0
# Entrance Fee in INR                   0
# Airport with 50km Radius              0
# Weekly Off                          293
# Significance                          0
# DSLR Allowed                          0
# Number of google review in lakhs      0
# Best Time to visit                    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 16 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        325 non-null    int64
#  1   Zone                              325 non-null    object
#  2   State                             325 non-null    object
#  3   City                              325 non-null    object
#  4   Name                              325 non-null    object
#  5   Type                              325 non-null    object
#  6   Establishment Year                325 non-null    object
#  7   time needed to visit in hrs       325 non-null    float64
#  8   Google review rating              325 non-null    float64
#  9   Entrance Fee in INR               325 non-null    int64
#  10  Airport with 50km Radius          325 non-null    object
# ...

# %%
df = df[df['Entrance Fee in INR'] != 0]
df
# Out:
#      Unnamed: 0           Zone                        State           City  \
# 3             3       Northern                        Delhi          Delhi
# 12           12       Northern                        Delhi          Delhi
# 13           13       Northern                        Delhi          Delhi
# 19           19        Western                   Maharastra         Mumbai
# 26           26        Western                   Maharastra       Lonavala
# 27           27       Southern                    Karnataka      Bangalore
# 32           32       Southern                    Telangana      Hyderabad
# 42           42        Eastern                  West Bengal        Kolkata
# 44           44        Eastern                  West Bengal        Kolkata
# 70           70        Western                      Gujarat       Vadodara
# 73           73        Western                      Gujarat        Kevadia
# ...

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29 entries, 3 to 322
# Data columns (total 16 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        29 non-null     int64
#  1   Zone                              29 non-null     object
#  2   State                             29 non-null     object
#  3   City                              29 non-null     object
#  4   Name                              29 non-null     object
#  5   Type                              29 non-null     object
#  6   Establishment Year                29 non-null     object
#  7   time needed to visit in hrs       29 non-null     float64
#  8   Google review rating              29 non-null     float64
#  9   Entrance Fee in INR               29 non-null     int64
#  10  Airport with 50km Radius          29 non-null     object
#  11  Weekly Off                        29 non-null     object
# ...

# %%
col = ['Type','Google review rating','Number of google review in lakhs','Entrance Fee in INR']
dfnew = df[col]
dfdummy = pd.get_dummies(dfnew,dtype=int)

# %%
x = dfdummy.drop(columns = ['Entrance Fee in INR'])
y = dfdummy['Entrance Fee in INR']

# %%
y
# Out:
# 3        50
# 12       20
# 13       80
# 19       50
# 26     1149
# 27      500
# 32       25
# 42       30
# 44       50
# 70      200
# 73      350
# 78      500
# 109     100
# 124      30
# 131      25
# 135      30
# 181      50
# 183      50
# 194     150
# 219      10
# 223      20
# 263      20
# 282      10
# 290      30
# 302    1100
# 310      50
# 315    1500
# 318      50
# 322      10
# Name: Entrance Fee in INR, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,shuffle = True)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x,y)
print(model.score(x_train,y_train))
print(model.score(x_test,y_test))
# Out:
# 0.9506134862803978
# 0.9617647704219051

# %%
from sklearn.linear_model import Lasso
reg1 = Lasso(alpha= 50,max_iter=100,tol= 0.1)
reg1.fit(x_train,y_train)
print(reg1.score(x_train,y_train))
print(reg1.score(x_test,y_test))
# Out:
# 0.4852897132942663
# 0.05372139840457302

# %%
from sklearn.linear_model import Ridge
reg2 = Ridge(alpha= 50,max_iter=100,tol= 0.1)
reg2.fit(x_train,y_train)
print(reg2.score(x_train,y_train))
print(reg2.score(x_test,y_test))
# Out:
# 0.3933199377546086
# 0.03720732895366852
